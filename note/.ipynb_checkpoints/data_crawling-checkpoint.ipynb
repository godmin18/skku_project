# %%
#보건복지부 코로나19 감염 현황 데이터 크롤링

import requests

serviceKey = "CLdvNcT3qtVeZJhdmUX5rlqieOMvkG2u2ehQPt3mgmou6mJeWuhgVisNt5zG7wYj3HCy1dGRLlq5e7qJf7hqwQ=="
url = 'http://openapi.data.go.kr/openapi/service/rest/Covid19/getCovid19InfStateJson'
params ={'serviceKey' : serviceKey, 
         'pageNo' : '1', 
         'numOfRows' : '10', 
         'startCreateDt' : '20200310', 
         'endCreateDt' : '20200315' }

response = requests.get(url, params=params)
print(response.content)
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header><resultCode>99</resultCode><resultMsg>SERVICE KEY IS NOT REGISTERED ERROR.</resultMsg></header></response>'

# %%
print(response)
# Out:
# <Response [200]>

# %%
# 코로나19 예방접종 통계 데이터 크롤링
# 
import requests
import json
import pandas as pd
from urllib import parse
from datetime import datetime, timedelta

serviceKey2 = "CLdvNcT3qtVeZJhdmUX5rlqieOMvkG2u2ehQPt3mgmou6mJeWuhgVisNt5zG7wYj3HCy1dGRLlq5e7qJf7hqwQ=="
url = 'https://api.odcloud.kr/api/15077756/v1/vaccine-stat'


#데이터 수집 기간 리스트화
def date_range(start, end):
    global dates
    start = datetime.strptime(start, "%Y-%m-%d")
    end = datetime.strptime(end, "%Y-%m-%d")
    dates = [(start + timedelta(days=i)).strftime("%Y-%m-%d 00:00:00") for i in range((end-start).days+1)]
    return dates

#일자별 전국기준 코로나 백신 접종 데이터 크롤링
def data_request(dates):
    datalist=[]
    for i in dates:
        query = [('cond[sido::EQ]', '전국'), ('cond[baseDate::EQ]', i)]
        query_param = url + '?' + parse.urlencode(query) + '&serviceKey=' + serviceKey2
        r = requests.get(query_param).text
        trans_json = json.loads(r)
        #if r.status_code != 200:
        #    err_msg = '%d, %s' %(r.status_code, r.reason)
        #    raise Exception(err_msg)
        datalist.append(trans_json)        
    return datalist

# json파일을 데이터프레임화
def to_DataFrame(dates):
    rows=[]
    for i in range(0, (len(dates)-1)):
        row=[]
        row.append(data[i]['data'][0]['accumulatedFirstCnt'])
        row.append(data[i]['data'][0]['accumulatedSecondCnt'])
        row.append(data[i]['data'][0]['accumulatedThirdCnt'])
        row.append(data[i]['data'][0]['baseDate'])
        row.append(data[i]['data'][0]['firstCnt'])
        row.append(data[i]['data'][0]['id'])
        row.append(data[i]['data'][0]['secondCnt'])
        row.append(data[i]['data'][0]['sido'])
        row.append(data[i]['data'][0]['thirdCnt'])
        row.append(data[i]['data'][0]['totalFirstCnt'])
        row.append(data[i]['data'][0]['totalSecondCnt'])
        row.append(data[i]['data'][0]['totalThirdCnt'])
        rows.append(row)
        
    df = pd.DataFrame(rows, columns=col_name)
    return df

def to_excel(dataframe):
    writer = pd.ExcelWriter('C:\\Users\\min\\Downloads\\df.xlsx', engine='xlsxwriter')
    dataframe.to_excel(writer, sheet_name='Sheet1')
    writer.close()

# %%
dates = date_range("2021-03-11", "2021-11-06")
data_request(dates)
# Out:
# [{'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 449535,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-11 00:00:00',
#     'firstCnt': 51100,
#     'id': 1,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 500635,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 503750,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-12 00:00:00',
#     'firstCnt': 42527,
#     'id': 19,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 546277,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 547974,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-13 00:00:00',
#     'firstCnt': 35684,
#     'id': 37,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 583658,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 584397,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-14 00:00:00',
#     'firstCnt': 3487,
#     'id': 55,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 587884,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 587884,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-15 00:00:00',
#     'firstCnt': 1074,
#     'id': 73,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 588958,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 590228,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-16 00:00:00',
#     'firstCnt': 11922,
#     'id': 91,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 602150,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 603451,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-17 00:00:00',
#     'firstCnt': 18283,
#     'id': 109,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 621734,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 622598,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-18 00:00:00',
#     'firstCnt': 18733,
#     'id': 127,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 641331,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 641974,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-19 00:00:00',
#     'firstCnt': 17501,
#     'id': 145,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 659475,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 660294,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-20 00:00:00',
#     'firstCnt': 15132,
#     'id': 163,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 675426,
#     'totalSecondCnt': 0,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 675648,
#     'accumulatedSecondCnt': 0,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-21 00:00:00',
#     'firstCnt': 939,
#     'id': 181,
#     'secondCnt': 313,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 676587,
#     'totalSecondCnt': 313,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 676606,
#     'accumulatedSecondCnt': 313,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-22 00:00:00',
#     'firstCnt': 1,
#     'id': 199,
#     'secondCnt': 280,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 676607,
#     'totalSecondCnt': 593,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 677856,
#     'accumulatedSecondCnt': 593,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-23 00:00:00',
#     'firstCnt': 2704,
#     'id': 217,
#     'secondCnt': 290,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 680560,
#     'totalSecondCnt': 883,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 683461,
#     'accumulatedSecondCnt': 883,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-24 00:00:00',
#     'firstCnt': 20151,
#     'id': 236,
#     'secondCnt': 615,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 703612,
#     'totalSecondCnt': 1498,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 704902,
#     'accumulatedSecondCnt': 1498,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-25 00:00:00',
#     'firstCnt': 28222,
#     'id': 254,
#     'secondCnt': 1193,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 733124,
#     'totalSecondCnt': 2691,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 734985,
#     'accumulatedSecondCnt': 2691,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-26 00:00:00',
#     'firstCnt': 32466,
#     'id': 272,
#     'secondCnt': 1142,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 767451,
#     'totalSecondCnt': 3833,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 769429,
#     'accumulatedSecondCnt': 3833,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-27 00:00:00',
#     'firstCnt': 22845,
#     'id': 290,
#     'secondCnt': 1399,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 792274,
#     'totalSecondCnt': 5232,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 792802,
#     'accumulatedSecondCnt': 5232,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-28 00:00:00',
#     'firstCnt': 1056,
#     'id': 308,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 793858,
#     'totalSecondCnt': 5232,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 793955,
#     'accumulatedSecondCnt': 5232,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-29 00:00:00',
#     'firstCnt': 11,
#     'id': 326,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 793966,
#     'totalSecondCnt': 5232,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 795910,
#     'accumulatedSecondCnt': 5232,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-30 00:00:00',
#     'firstCnt': 26538,
#     'id': 344,
#     'secondCnt': 919,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 822448,
#     'totalSecondCnt': 6151,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 823795,
#     'accumulatedSecondCnt': 6151,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-03-31 00:00:00',
#     'firstCnt': 28407,
#     'id': 362,
#     'secondCnt': 2034,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 852202,
#     'totalSecondCnt': 8185,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 853930,
#     'accumulatedSecondCnt': 8187,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-01 00:00:00',
#     'firstCnt': 22643,
#     'id': 380,
#     'secondCnt': 4786,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 876573,
#     'totalSecondCnt': 12973,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 877944,
#     'accumulatedSecondCnt': 12974,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-02 00:00:00',
#     'firstCnt': 36125,
#     'id': 398,
#     'secondCnt': 6881,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 914069,
#     'totalSecondCnt': 19855,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 915498,
#     'accumulatedSecondCnt': 20203,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-03 00:00:00',
#     'firstCnt': 38058,
#     'id': 416,
#     'secondCnt': 6177,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 953556,
#     'totalSecondCnt': 26380,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 953854,
#     'accumulatedSecondCnt': 26761,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-04 00:00:00',
#     'firstCnt': 8229,
#     'id': 434,
#     'secondCnt': 537,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 962083,
#     'totalSecondCnt': 27298,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 962101,
#     'accumulatedSecondCnt': 27298,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-05 00:00:00',
#     'firstCnt': 629,
#     'id': 452,
#     'secondCnt': 66,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 962730,
#     'totalSecondCnt': 27364,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 963900,
#     'accumulatedSecondCnt': 27375,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-06 00:00:00',
#     'firstCnt': 35970,
#     'id': 470,
#     'secondCnt': 316,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 999870,
#     'totalSecondCnt': 27691,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1001533,
#     'accumulatedSecondCnt': 27692,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-07 00:00:00',
#     'firstCnt': 37533,
#     'id': 488,
#     'secondCnt': 5722,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1039066,
#     'totalSecondCnt': 33414,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1039714,
#     'accumulatedSecondCnt': 33416,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-08 00:00:00',
#     'firstCnt': 35860,
#     'id': 506,
#     'secondCnt': 9231,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1075574,
#     'totalSecondCnt': 42647,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1077067,
#     'accumulatedSecondCnt': 42646,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-09 00:00:00',
#     'firstCnt': 36599,
#     'id': 524,
#     'secondCnt': 9490,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1113666,
#     'totalSecondCnt': 52136,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1114656,
#     'accumulatedSecondCnt': 52144,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-10 00:00:00',
#     'firstCnt': 33404,
#     'id': 542,
#     'secondCnt': 7278,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1148060,
#     'totalSecondCnt': 59422,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1148240,
#     'accumulatedSecondCnt': 59422,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-11 00:00:00',
#     'firstCnt': 8710,
#     'id': 560,
#     'secondCnt': 1088,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1156950,
#     'totalSecondCnt': 60510,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1156950,
#     'accumulatedSecondCnt': 60511,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-12 00:00:00',
#     'firstCnt': 305,
#     'id': 578,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1157255,
#     'totalSecondCnt': 60511,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1157557,
#     'accumulatedSecondCnt': 60532,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-13 00:00:00',
#     'firstCnt': 37785,
#     'id': 596,
#     'secondCnt': 25,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1195342,
#     'totalSecondCnt': 60557,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1195676,
#     'accumulatedSecondCnt': 60564,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-14 00:00:00',
#     'firstCnt': 43390,
#     'id': 614,
#     'secondCnt': 3,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1239066,
#     'totalSecondCnt': 60567,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1240389,
#     'accumulatedSecondCnt': 60567,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-15 00:00:00',
#     'firstCnt': 45520,
#     'id': 632,
#     'secondCnt': 2,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1285909,
#     'totalSecondCnt': 60569,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1286993,
#     'accumulatedSecondCnt': 60569,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-16 00:00:00',
#     'firstCnt': 92660,
#     'id': 650,
#     'secondCnt': 2,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1379653,
#     'totalSecondCnt': 60571,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1380579,
#     'accumulatedSecondCnt': 60571,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-17 00:00:00',
#     'firstCnt': 102390,
#     'id': 668,
#     'secondCnt': 6,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1482969,
#     'totalSecondCnt': 60577,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1483338,
#     'accumulatedSecondCnt': 60585,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-18 00:00:00',
#     'firstCnt': 29165,
#     'id': 686,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1512503,
#     'totalSecondCnt': 60585,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1512531,
#     'accumulatedSecondCnt': 60585,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-19 00:00:00',
#     'firstCnt': 4859,
#     'id': 704,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1517390,
#     'totalSecondCnt': 60585,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1518256,
#     'accumulatedSecondCnt': 60585,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-20 00:00:00',
#     'firstCnt': 121234,
#     'id': 722,
#     'secondCnt': 1,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1639490,
#     'totalSecondCnt': 60586,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1641179,
#     'accumulatedSecondCnt': 60586,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-21 00:00:00',
#     'firstCnt': 130228,
#     'id': 740,
#     'secondCnt': 11,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1771407,
#     'totalSecondCnt': 60597,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1772539,
#     'accumulatedSecondCnt': 60597,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-22 00:00:00',
#     'firstCnt': 131228,
#     'id': 758,
#     'secondCnt': 25,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 1903767,
#     'totalSecondCnt': 60622,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 1904934,
#     'accumulatedSecondCnt': 60623,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-23 00:00:00',
#     'firstCnt': 130615,
#     'id': 777,
#     'secondCnt': 18528,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2035549,
#     'totalSecondCnt': 79151,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2036911,
#     'accumulatedSecondCnt': 79154,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-24 00:00:00',
#     'firstCnt': 158581,
#     'id': 796,
#     'secondCnt': 19613,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2195492,
#     'totalSecondCnt': 98767,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2196295,
#     'accumulatedSecondCnt': 98769,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-25 00:00:00',
#     'firstCnt': 64344,
#     'id': 815,
#     'secondCnt': 5769,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2260639,
#     'totalSecondCnt': 104538,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2260748,
#     'accumulatedSecondCnt': 104538,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-26 00:00:00',
#     'firstCnt': 6140,
#     'id': 834,
#     'secondCnt': 367,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2266888,
#     'totalSecondCnt': 104905,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2268038,
#     'accumulatedSecondCnt': 104905,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-27 00:00:00',
#     'firstCnt': 141937,
#     'id': 853,
#     'secondCnt': 21598,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2409975,
#     'totalSecondCnt': 126503,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2410975,
#     'accumulatedSecondCnt': 126506,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-28 00:00:00',
#     'firstCnt': 175794,
#     'id': 871,
#     'secondCnt': 21776,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2586769,
#     'totalSecondCnt': 148282,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2588065,
#     'accumulatedSecondCnt': 148286,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-29 00:00:00',
#     'firstCnt': 220729,
#     'id': 889,
#     'secondCnt': 20435,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 2808794,
#     'totalSecondCnt': 168721,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 2814037,
#     'accumulatedSecondCnt': 168724,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-04-30 00:00:00',
#     'firstCnt': 241967,
#     'id': 907,
#     'secondCnt': 30010,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3056004,
#     'totalSecondCnt': 198734,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3066985,
#     'accumulatedSecondCnt': 198744,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-01 00:00:00',
#     'firstCnt': 259018,
#     'id': 925,
#     'secondCnt': 29655,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3326003,
#     'totalSecondCnt': 228399,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3355935,
#     'accumulatedSecondCnt': 228476,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-02 00:00:00',
#     'firstCnt': 39169,
#     'id': 943,
#     'secondCnt': 7712,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3395104,
#     'totalSecondCnt': 236188,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3395303,
#     'accumulatedSecondCnt': 236188,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-03 00:00:00',
#     'firstCnt': 1561,
#     'id': 961,
#     'secondCnt': 301,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3396864,
#     'totalSecondCnt': 236489,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3399988,
#     'accumulatedSecondCnt': 236494,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-04 00:00:00',
#     'firstCnt': 66920,
#     'id': 979,
#     'secondCnt': 30538,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3466908,
#     'totalSecondCnt': 267032,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3467507,
#     'accumulatedSecondCnt': 267033,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-05 00:00:00',
#     'firstCnt': 62507,
#     'id': 997,
#     'secondCnt': 31159,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3530014,
#     'totalSecondCnt': 298192,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3555071,
#     'accumulatedSecondCnt': 298195,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-06 00:00:00',
#     'firstCnt': 5253,
#     'id': 1015,
#     'secondCnt': 25310,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3560324,
#     'totalSecondCnt': 323505,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3566651,
#     'accumulatedSecondCnt': 323699,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-07 00:00:00',
#     'firstCnt': 41965,
#     'id': 1033,
#     'secondCnt': 73491,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3608616,
#     'totalSecondCnt': 397190,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3623605,
#     'accumulatedSecondCnt': 397204,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-08 00:00:00',
#     'firstCnt': 38982,
#     'id': 1051,
#     'secondCnt': 76790,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3662587,
#     'totalSecondCnt': 473994,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3662751,
#     'accumulatedSecondCnt': 473993,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-09 00:00:00',
#     'firstCnt': 11931,
#     'id': 1069,
#     'secondCnt': 27546,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3674682,
#     'totalSecondCnt': 501539,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3674726,
#     'accumulatedSecondCnt': 501540,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-10 00:00:00',
#     'firstCnt': 3,
#     'id': 1087,
#     'secondCnt': 4734,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3674729,
#     'totalSecondCnt': 506274,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3684225,
#     'accumulatedSecondCnt': 506462,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-11 00:00:00',
#     'firstCnt': 8341,
#     'id': 1105,
#     'secondCnt': 77551,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3692566,
#     'totalSecondCnt': 584013,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3692628,
#     'accumulatedSecondCnt': 584025,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-12 00:00:00',
#     'firstCnt': 6029,
#     'id': 1123,
#     'secondCnt': 80788,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3698657,
#     'totalSecondCnt': 664813,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3706615,
#     'accumulatedSecondCnt': 664817,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-13 00:00:00',
#     'firstCnt': 4408,
#     'id': 1141,
#     'secondCnt': 82890,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3711023,
#     'totalSecondCnt': 747707,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3712844,
#     'accumulatedSecondCnt': 747713,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-14 00:00:00',
#     'firstCnt': 7139,
#     'id': 1159,
#     'secondCnt': 77987,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3719983,
#     'totalSecondCnt': 825700,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3721673,
#     'accumulatedSecondCnt': 825715,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-15 00:00:00',
#     'firstCnt': 9548,
#     'id': 1177,
#     'secondCnt': 79705,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3731221,
#     'totalSecondCnt': 905420,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3732527,
#     'accumulatedSecondCnt': 905528,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-16 00:00:00',
#     'firstCnt': 1269,
#     'id': 1195,
#     'secondCnt': 29829,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3733796,
#     'totalSecondCnt': 935357,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3733801,
#     'accumulatedSecondCnt': 935359,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-17 00:00:00',
#     'firstCnt': 5,
#     'id': 1213,
#     'secondCnt': 4986,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3733806,
#     'totalSecondCnt': 940345,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3733928,
#     'accumulatedSecondCnt': 940694,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-18 00:00:00',
#     'firstCnt': 12006,
#     'id': 1231,
#     'secondCnt': 98948,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3745934,
#     'totalSecondCnt': 1039642,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3747236,
#     'accumulatedSecondCnt': 1040603,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-19 00:00:00',
#     'firstCnt': 11822,
#     'id': 1249,
#     'secondCnt': 139678,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3759058,
#     'totalSecondCnt': 1180281,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3759157,
#     'accumulatedSecondCnt': 1180516,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-20 00:00:00',
#     'firstCnt': 1783,
#     'id': 1267,
#     'secondCnt': 92694,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3760940,
#     'totalSecondCnt': 1273210,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3761416,
#     'accumulatedSecondCnt': 1275047,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-21 00:00:00',
#     'firstCnt': 11183,
#     'id': 1285,
#     'secondCnt': 207795,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3772599,
#     'totalSecondCnt': 1482842,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3773806,
#     'accumulatedSecondCnt': 1485612,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-22 00:00:00',
#     'firstCnt': 13764,
#     'id': 1303,
#     'secondCnt': 221916,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3787570,
#     'totalSecondCnt': 1707528,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3787727,
#     'accumulatedSecondCnt': 1708854,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-23 00:00:00',
#     'firstCnt': 4933,
#     'id': 1321,
#     'secondCnt': 34583,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3792660,
#     'totalSecondCnt': 1743437,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3792689,
#     'accumulatedSecondCnt': 1743627,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-24 00:00:00',
#     'firstCnt': 217,
#     'id': 1339,
#     'secondCnt': 2709,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3792906,
#     'totalSecondCnt': 1746336,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3793492,
#     'accumulatedSecondCnt': 1748792,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-25 00:00:00',
#     'firstCnt': 71292,
#     'id': 1357,
#     'secondCnt': 101877,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3864784,
#     'totalSecondCnt': 1850669,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3865303,
#     'accumulatedSecondCnt': 1853619,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-26 00:00:00',
#     'firstCnt': 77472,
#     'id': 1375,
#     'secondCnt': 91598,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 3942775,
#     'totalSecondCnt': 1945217,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 3943579,
#     'accumulatedSecondCnt': 1946983,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-27 00:00:00',
#     'firstCnt': 87165,
#     'id': 1393,
#     'secondCnt': 65936,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 4030744,
#     'totalSecondCnt': 2012919,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 4031328,
#     'accumulatedSecondCnt': 2014875,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-28 00:00:00',
#     'firstCnt': 657192,
#     'id': 1411,
#     'secondCnt': 54002,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 4688520,
#     'totalSecondCnt': 2068877,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 4691736,
#     'accumulatedSecondCnt': 2069844,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-29 00:00:00',
#     'firstCnt': 542227,
#     'id': 1429,
#     'secondCnt': 63876,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 5233963,
#     'totalSecondCnt': 2133720,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 5235558,
#     'accumulatedSecondCnt': 2134761,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-30 00:00:00',
#     'firstCnt': 163457,
#     'id': 1447,
#     'secondCnt': 8532,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 5399015,
#     'totalSecondCnt': 2143293,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 5399144,
#     'accumulatedSecondCnt': 2143298,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-05-31 00:00:00',
#     'firstCnt': 4710,
#     'id': 1465,
#     'secondCnt': 87,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 5403854,
#     'totalSecondCnt': 2143385,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 5405968,
#     'accumulatedSecondCnt': 2144272,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-01 00:00:00',
#     'firstCnt': 385535,
#     'id': 1483,
#     'secondCnt': 27064,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 5791503,
#     'totalSecondCnt': 2171336,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 5793135,
#     'accumulatedSecondCnt': 2172065,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-02 00:00:00',
#     'firstCnt': 565377,
#     'id': 1501,
#     'secondCnt': 25945,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 6358512,
#     'totalSecondCnt': 2198010,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 6360442,
#     'accumulatedSecondCnt': 2198499,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-03 00:00:00',
#     'firstCnt': 381551,
#     'id': 1519,
#     'secondCnt': 22229,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 6741993,
#     'totalSecondCnt': 2220728,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 6743716,
#     'accumulatedSecondCnt': 2221504,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-04 00:00:00',
#     'firstCnt': 342576,
#     'id': 1537,
#     'secondCnt': 25504,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 7086292,
#     'totalSecondCnt': 2247008,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 7087965,
#     'accumulatedSecondCnt': 2247553,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-05 00:00:00',
#     'firstCnt': 367761,
#     'id': 1555,
#     'secondCnt': 29584,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 7455726,
#     'totalSecondCnt': 2277137,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 7456423,
#     'accumulatedSecondCnt': 2277245,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-06 00:00:00',
#     'firstCnt': 138649,
#     'id': 1573,
#     'secondCnt': 2351,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 7595072,
#     'totalSecondCnt': 2279596,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 7595829,
#     'accumulatedSecondCnt': 2279682,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-07 00:00:00',
#     'firstCnt': 2958,
#     'id': 1591,
#     'secondCnt': 0,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 7598787,
#     'totalSecondCnt': 2279682,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 7600157,
#     'accumulatedSecondCnt': 2279997,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-08 00:00:00',
#     'firstCnt': 855642,
#     'id': 1609,
#     'secondCnt': 19856,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 8455799,
#     'totalSecondCnt': 2299853,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 8487962,
#     'accumulatedSecondCnt': 2300509,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-09 00:00:00',
#     'firstCnt': 714384,
#     'id': 1627,
#     'secondCnt': 24750,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 9202346,
#     'totalSecondCnt': 2325259,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 9232076,
#     'accumulatedSecondCnt': 2325957,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-10 00:00:00',
#     'firstCnt': 562087,
#     'id': 1645,
#     'secondCnt': 23528,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 9794163,
#     'totalSecondCnt': 2349485,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 9832337,
#     'accumulatedSecondCnt': 2350687,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-11 00:00:00',
#     'firstCnt': 733067,
#     'id': 1663,
#     'secondCnt': 285448,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 10565404,
#     'totalSecondCnt': 2636135,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 10594421,
#     'accumulatedSecondCnt': 2638114,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-12 00:00:00',
#     'firstCnt': 792835,
#     'id': 1681,
#     'secondCnt': 235748,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 11387256,
#     'totalSecondCnt': 2873862,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 11416064,
#     'accumulatedSecondCnt': 2874527,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-13 00:00:00',
#     'firstCnt': 386223,
#     'id': 1699,
#     'secondCnt': 117602,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 11802287,
#     'totalSecondCnt': 2992129,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 11802900,
#     'accumulatedSecondCnt': 2992255,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-14 00:00:00',
#     'firstCnt': 27481,
#     'id': 1717,
#     'secondCnt': 11774,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 11830381,
#     'totalSecondCnt': 3004029,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 11833534,
#     'accumulatedSecondCnt': 3006290,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-15 00:00:00',
#     'firstCnt': 731735,
#     'id': 1735,
#     'secondCnt': 256443,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 12565269,
#     'totalSecondCnt': 3262733,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 12602026,
#     'accumulatedSecondCnt': 3265037,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-16 00:00:00',
#     'firstCnt': 617181,
#     'id': 1753,
#     'secondCnt': 207339,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 13219207,
#     'totalSecondCnt': 3472376,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 13250593,
#     'accumulatedSecondCnt': 3474112,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-17 00:00:00',
#     'firstCnt': 540248,
#     'id': 1771,
#     'secondCnt': 280928,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 13790841,
#     'totalSecondCnt': 3755040,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 13820058,
#     'accumulatedSecondCnt': 3757067,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-18 00:00:00',
#     'firstCnt': 412987,
#     'id': 1789,
#     'secondCnt': 127643,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 14233045,
#     'totalSecondCnt': 3884710,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 14261046,
#     'accumulatedSecondCnt': 3886535,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-19 00:00:00',
#     'firstCnt': 507319,
#     'id': 1807,
#     'secondCnt': 126036,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 14768365,
#     'totalSecondCnt': 4012571,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 14800465,
#     'accumulatedSecondCnt': 4013089,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-20 00:00:00',
#     'firstCnt': 211990,
#     'id': 1825,
#     'secondCnt': 33522,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15012455,
#     'totalSecondCnt': 4046611,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15014314,
#     'accumulatedSecondCnt': 4046808,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-21 00:00:00',
#     'firstCnt': 505,
#     'id': 1843,
#     'secondCnt': 1038,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15014819,
#     'totalSecondCnt': 4047846,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15019767,
#     'accumulatedSecondCnt': 4051080,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-22 00:00:00',
#     'firstCnt': 20231,
#     'id': 1861,
#     'secondCnt': 116453,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15039998,
#     'totalSecondCnt': 4167533,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15068519,
#     'accumulatedSecondCnt': 4168857,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-23 00:00:00',
#     'firstCnt': 30346,
#     'id': 1879,
#     'secondCnt': 123415,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15098865,
#     'totalSecondCnt': 4292272,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15121636,
#     'accumulatedSecondCnt': 4294377,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-24 00:00:00',
#     'firstCnt': 28485,
#     'id': 1897,
#     'secondCnt': 119117,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15150121,
#     'totalSecondCnt': 4413494,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15168599,
#     'accumulatedSecondCnt': 4414987,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-25 00:00:00',
#     'firstCnt': 31320,
#     'id': 1915,
#     'secondCnt': 106798,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15199919,
#     'totalSecondCnt': 4521785,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15216892,
#     'accumulatedSecondCnt': 4522789,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-26 00:00:00',
#     'firstCnt': 46333,
#     'id': 1933,
#     'secondCnt': 96129,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15263225,
#     'totalSecondCnt': 4618918,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15279057,
#     'accumulatedSecondCnt': 4620427,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-27 00:00:00',
#     'firstCnt': 11159,
#     'id': 1951,
#     'secondCnt': 22784,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15290216,
#     'totalSecondCnt': 4643211,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15290296,
#     'accumulatedSecondCnt': 4643211,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-28 00:00:00',
#     'firstCnt': 6,
#     'id': 1969,
#     'secondCnt': 740,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15290302,
#     'totalSecondCnt': 4643951,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15291417,
#     'accumulatedSecondCnt': 4645673,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-29 00:00:00',
#     'firstCnt': 12703,
#     'id': 1987,
#     'secondCnt': 112722,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15304120,
#     'totalSecondCnt': 4758395,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15305170,
#     'accumulatedSecondCnt': 4789232,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-06-30 00:00:00',
#     'firstCnt': 16084,
#     'id': 2005,
#     'secondCnt': 116230,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15321254,
#     'totalSecondCnt': 4905462,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 15322128,
#     'accumulatedSecondCnt': 4933545,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-07-01 00:00:00',
#     'firstCnt': 14233,
#     'id': 2023,
#     'secondCnt': 107695,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 15336361,
#     'totalSecondCnt': 5041240,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
# ...
#   'data': [{'accumulatedFirstCnt': 39003821,
#     'accumulatedSecondCnt': 25171866,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-01 00:00:00',
#     'firstCnt': 343752,
#     'id': 3679,
#     'secondCnt': 541143,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39347573,
#     'totalSecondCnt': 25713009,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39348997,
#     'accumulatedSecondCnt': 25714715,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-02 00:00:00',
#     'firstCnt': 236268,
#     'id': 3697,
#     'secondCnt': 859970,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39585265,
#     'totalSecondCnt': 26574685,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39585966,
#     'accumulatedSecondCnt': 26576280,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-03 00:00:00',
#     'firstCnt': 124504,
#     'id': 3715,
#     'secondCnt': 406444,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39710470,
#     'totalSecondCnt': 26982724,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39710596,
#     'accumulatedSecondCnt': 26983001,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-04 00:00:00',
#     'firstCnt': 3404,
#     'id': 3733,
#     'secondCnt': 33187,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39714000,
#     'totalSecondCnt': 27016188,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39714150,
#     'accumulatedSecondCnt': 27016649,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-05 00:00:00',
#     'firstCnt': 25355,
#     'id': 3751,
#     'secondCnt': 209328,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39739505,
#     'totalSecondCnt': 27225977,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39740778,
#     'accumulatedSecondCnt': 27228258,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-06 00:00:00',
#     'firstCnt': 44879,
#     'id': 3769,
#     'secondCnt': 765885,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39785657,
#     'totalSecondCnt': 27994143,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39787211,
#     'accumulatedSecondCnt': 27996194,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-07 00:00:00',
#     'firstCnt': 36770,
#     'id': 3787,
#     'secondCnt': 510161,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39823981,
#     'totalSecondCnt': 28506355,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39826227,
#     'accumulatedSecondCnt': 28510014,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-08 00:00:00',
#     'firstCnt': 36187,
#     'id': 3805,
#     'secondCnt': 710173,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39862414,
#     'totalSecondCnt': 29220187,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39865342,
#     'accumulatedSecondCnt': 29224027,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-09 00:00:00',
#     'firstCnt': 43782,
#     'id': 3823,
#     'secondCnt': 1098170,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39909124,
#     'totalSecondCnt': 30322197,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39910153,
#     'accumulatedSecondCnt': 30322973,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-10 00:00:00',
#     'firstCnt': 10766,
#     'id': 3841,
#     'secondCnt': 103426,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39920919,
#     'totalSecondCnt': 30426399,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39921024,
#     'accumulatedSecondCnt': 30426651,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-11 00:00:00',
#     'firstCnt': 2723,
#     'id': 3859,
#     'secondCnt': 18049,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 39923747,
#     'totalSecondCnt': 30444700,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 39923916,
#     'accumulatedSecondCnt': 30445566,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-12 00:00:00',
#     'firstCnt': 90817,
#     'id': 3877,
#     'secondCnt': 160482,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 40014733,
#     'totalSecondCnt': 30606048,
#     'totalThirdCnt': 0}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40020307,
#     'accumulatedSecondCnt': 30614670,
#     'accumulatedThirdCnt': 0,
#     'baseDate': '2021-10-13 00:00:00',
#     'firstCnt': 104897,
#     'id': 3895,
#     'secondCnt': 594230,
#     'sido': '전국',
#     'thirdCnt': 515,
#     'totalFirstCnt': 40125204,
#     'totalSecondCnt': 31208900,
#     'totalThirdCnt': 515}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40129084,
#     'accumulatedSecondCnt': 31218008,
#     'accumulatedThirdCnt': 516,
#     'baseDate': '2021-10-14 00:00:00',
#     'firstCnt': 56619,
#     'id': 3913,
#     'secondCnt': 407096,
#     'sido': '전국',
#     'thirdCnt': 991,
#     'totalFirstCnt': 40185703,
#     'totalSecondCnt': 31625104,
#     'totalThirdCnt': 1507}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40188671,
#     'accumulatedSecondCnt': 31631228,
#     'accumulatedThirdCnt': 1627,
#     'baseDate': '2021-10-15 00:00:00',
#     'firstCnt': 53758,
#     'id': 3931,
#     'secondCnt': 452660,
#     'sido': '전국',
#     'thirdCnt': 1369,
#     'totalFirstCnt': 40242429,
#     'totalSecondCnt': 32083888,
#     'totalThirdCnt': 2996}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40245160,
#     'accumulatedSecondCnt': 32091462,
#     'accumulatedThirdCnt': 3218,
#     'baseDate': '2021-10-16 00:00:00',
#     'firstCnt': 87867,
#     'id': 3949,
#     'secondCnt': 718818,
#     'sido': '전국',
#     'thirdCnt': 2180,
#     'totalFirstCnt': 40333027,
#     'totalSecondCnt': 32810280,
#     'totalThirdCnt': 5398}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40334523,
#     'accumulatedSecondCnt': 32812317,
#     'accumulatedThirdCnt': 5485,
#     'baseDate': '2021-10-17 00:00:00',
#     'firstCnt': 63954,
#     'id': 3967,
#     'secondCnt': 353781,
#     'sido': '전국',
#     'thirdCnt': 90,
#     'totalFirstCnt': 40398477,
#     'totalSecondCnt': 33166098,
#     'totalThirdCnt': 5575}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40398773,
#     'accumulatedSecondCnt': 33166732,
#     'accumulatedThirdCnt': 5575,
#     'baseDate': '2021-10-18 00:00:00',
#     'firstCnt': 1489,
#     'id': 3985,
#     'secondCnt': 18883,
#     'sido': '전국',
#     'thirdCnt': 0,
#     'totalFirstCnt': 40400262,
#     'totalSecondCnt': 33185615,
#     'totalThirdCnt': 5575}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40402877,
#     'accumulatedSecondCnt': 33189677,
#     'accumulatedThirdCnt': 5752,
#     'baseDate': '2021-10-19 00:00:00',
#     'firstCnt': 71635,
#     'id': 4003,
#     'secondCnt': 628733,
#     'sido': '전국',
#     'thirdCnt': 1393,
#     'totalFirstCnt': 40474512,
#     'totalSecondCnt': 33818410,
#     'totalThirdCnt': 7145}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40476314,
#     'accumulatedSecondCnt': 33821739,
#     'accumulatedThirdCnt': 7269,
#     'baseDate': '2021-10-20 00:00:00',
#     'firstCnt': 36777,
#     'id': 4021,
#     'secondCnt': 443345,
#     'sido': '전국',
#     'thirdCnt': 1784,
#     'totalFirstCnt': 40513091,
#     'totalSecondCnt': 34265084,
#     'totalThirdCnt': 9053}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40515521,
#     'accumulatedSecondCnt': 34271438,
#     'accumulatedThirdCnt': 9140,
#     'baseDate': '2021-10-21 00:00:00',
#     'firstCnt': 68492,
#     'id': 4039,
#     'secondCnt': 321965,
#     'sido': '전국',
#     'thirdCnt': 3861,
#     'totalFirstCnt': 40584013,
#     'totalSecondCnt': 34593403,
#     'totalThirdCnt': 13001}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40586309,
#     'accumulatedSecondCnt': 34597983,
#     'accumulatedThirdCnt': 13017,
#     'baseDate': '2021-10-22 00:00:00',
#     'firstCnt': 58594,
#     'id': 4057,
#     'secondCnt': 405795,
#     'sido': '전국',
#     'thirdCnt': 4981,
#     'totalFirstCnt': 40644903,
#     'totalSecondCnt': 35003778,
#     'totalThirdCnt': 17998}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40647284,
#     'accumulatedSecondCnt': 35009036,
#     'accumulatedThirdCnt': 18889,
#     'baseDate': '2021-10-23 00:00:00',
#     'firstCnt': 62946,
#     'id': 4075,
#     'secondCnt': 621014,
#     'sido': '전국',
#     'thirdCnt': 5636,
#     'totalFirstCnt': 40710230,
#     'totalSecondCnt': 35630050,
#     'totalThirdCnt': 24525}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40713014,
#     'accumulatedSecondCnt': 35642855,
#     'accumulatedThirdCnt': 24702,
#     'baseDate': '2021-10-24 00:00:00',
#     'firstCnt': 51227,
#     'id': 4093,
#     'secondCnt': 332557,
#     'sido': '전국',
#     'thirdCnt': 492,
#     'totalFirstCnt': 40764241,
#     'totalSecondCnt': 35975412,
#     'totalThirdCnt': 25194}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40764384,
#     'accumulatedSecondCnt': 35976328,
#     'accumulatedThirdCnt': 25194,
#     'baseDate': '2021-10-25 00:00:00',
#     'firstCnt': 3730,
#     'id': 4111,
#     'secondCnt': 16380,
#     'sido': '전국',
#     'thirdCnt': 2,
#     'totalFirstCnt': 40768114,
#     'totalSecondCnt': 35992708,
#     'totalThirdCnt': 25196}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40770450,
#     'accumulatedSecondCnt': 35996202,
#     'accumulatedThirdCnt': 25361,
#     'baseDate': '2021-10-26 00:00:00',
#     'firstCnt': 77434,
#     'id': 4129,
#     'secondCnt': 427919,
#     'sido': '전국',
#     'thirdCnt': 8795,
#     'totalFirstCnt': 40847884,
#     'totalSecondCnt': 36424121,
#     'totalThirdCnt': 34156}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40850783,
#     'accumulatedSecondCnt': 36431541,
#     'accumulatedThirdCnt': 34286,
#     'baseDate': '2021-10-27 00:00:00',
#     'firstCnt': 40305,
#     'id': 4147,
#     'secondCnt': 278236,
#     'sido': '전국',
#     'thirdCnt': 12235,
#     'totalFirstCnt': 40891088,
#     'totalSecondCnt': 36709777,
#     'totalThirdCnt': 46521}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40894082,
#     'accumulatedSecondCnt': 36715234,
#     'accumulatedThirdCnt': 47317,
#     'baseDate': '2021-10-28 00:00:00',
#     'firstCnt': 76802,
#     'id': 4165,
#     'secondCnt': 255616,
#     'sido': '전국',
#     'thirdCnt': 12412,
#     'totalFirstCnt': 40970884,
#     'totalSecondCnt': 36970850,
#     'totalThirdCnt': 59729}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 40973956,
#     'accumulatedSecondCnt': 36975677,
#     'accumulatedThirdCnt': 59850,
#     'baseDate': '2021-10-29 00:00:00',
#     'firstCnt': 61941,
#     'id': 4183,
#     'secondCnt': 617785,
#     'sido': '전국',
#     'thirdCnt': 8567,
#     'totalFirstCnt': 41035897,
#     'totalSecondCnt': 37593462,
#     'totalThirdCnt': 68417}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41039143,
#     'accumulatedSecondCnt': 37601761,
#     'accumulatedThirdCnt': 68664,
#     'baseDate': '2021-10-30 00:00:00',
#     'firstCnt': 58513,
#     'id': 4201,
#     'secondCnt': 689085,
#     'sido': '전국',
#     'thirdCnt': 9136,
#     'totalFirstCnt': 41097656,
#     'totalSecondCnt': 38290846,
#     'totalThirdCnt': 77800}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41099894,
#     'accumulatedSecondCnt': 38303341,
#     'accumulatedThirdCnt': 77944,
#     'baseDate': '2021-10-31 00:00:00',
#     'firstCnt': 36103,
#     'id': 4219,
#     'secondCnt': 357137,
#     'sido': '전국',
#     'thirdCnt': 3280,
#     'totalFirstCnt': 41135997,
#     'totalSecondCnt': 38660478,
#     'totalThirdCnt': 81224}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41136056,
#     'accumulatedSecondCnt': 38660848,
#     'accumulatedThirdCnt': 81224,
#     'baseDate': '2021-11-01 00:00:00',
#     'firstCnt': 2736,
#     'id': 4237,
#     'secondCnt': 20354,
#     'sido': '전국',
#     'thirdCnt': 193,
#     'totalFirstCnt': 41138792,
#     'totalSecondCnt': 38681202,
#     'totalThirdCnt': 81417}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41141814,
#     'accumulatedSecondCnt': 38686286,
#     'accumulatedThirdCnt': 81896,
#     'baseDate': '2021-11-02 00:00:00',
#     'firstCnt': 82747,
#     'id': 4255,
#     'secondCnt': 118436,
#     'sido': '전국',
#     'thirdCnt': 34010,
#     'totalFirstCnt': 41224561,
#     'totalSecondCnt': 38804722,
#     'totalThirdCnt': 115906}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41227277,
#     'accumulatedSecondCnt': 38808119,
#     'accumulatedThirdCnt': 116364,
#     'baseDate': '2021-11-03 00:00:00',
#     'firstCnt': 42176,
#     'id': 4273,
#     'secondCnt': 87113,
#     'sido': '전국',
#     'thirdCnt': 55974,
#     'totalFirstCnt': 41269453,
#     'totalSecondCnt': 38895232,
#     'totalThirdCnt': 172338}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41271990,
#     'accumulatedSecondCnt': 38898040,
#     'accumulatedThirdCnt': 172987,
#     'baseDate': '2021-11-04 00:00:00',
#     'firstCnt': 64307,
#     'id': 4291,
#     'secondCnt': 75539,
#     'sido': '전국',
#     'thirdCnt': 56585,
#     'totalFirstCnt': 41336297,
#     'totalSecondCnt': 38973579,
#     'totalThirdCnt': 229572}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 1,
#   'data': [{'accumulatedFirstCnt': 41338564,
#     'accumulatedSecondCnt': 38976091,
#     'accumulatedThirdCnt': 230262,
#     'baseDate': '2021-11-05 00:00:00',
#     'firstCnt': 60047,
#     'id': 4309,
#     'secondCnt': 123194,
#     'sido': '전국',
#     'thirdCnt': 44331,
#     'totalFirstCnt': 41398611,
#     'totalSecondCnt': 39099285,
#     'totalThirdCnt': 274593}],
#   'matchCount': 1,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326},
#  {'currentCount': 0,
#   'data': [],
#   'matchCount': 0,
#   'page': 1,
#   'perPage': 10,
#   'totalCount': 4326}]

# %%
to_DataFrame(dates)
# Out:
#      accumulatedFirstCnt  accumulatedSecondCnt  accumulatedThirdCnt  \
# 0                 449535                     0                    0
# 1                 503750                     0                    0
# 2                 547974                     0                    0
# 3                 584397                     0                    0
# 4                 587884                     0                    0
# ..                   ...                   ...                  ...
# 235             41136056              38660848                81224
# 236             41141814              38686286                81896
# 237             41227277              38808119               116364
# 238             41271990              38898040               172987
# 239             41338564              38976091               230262
#
#                 baseDate  firstCnt    id  secondCnt sido  thirdCnt  \
# 0    2021-03-11 00:00:00     51100     1          0   전국         0
# 1    2021-03-12 00:00:00     42527    19          0   전국         0
# 2    2021-03-13 00:00:00     35684    37          0   전국         0
# 3    2021-03-14 00:00:00      3487    55          0   전국         0
# 4    2021-03-15 00:00:00      1074    73          0   전국         0
# ..                   ...       ...   ...        ...  ...       ...
# 235  2021-11-01 00:00:00      2736  4237      20354   전국       193
# 236  2021-11-02 00:00:00     82747  4255     118436   전국     34010
# 237  2021-11-03 00:00:00     42176  4273      87113   전국     55974
# 238  2021-11-04 00:00:00     64307  4291      75539   전국     56585
# 239  2021-11-05 00:00:00     60047  4309     123194   전국     44331
#
#      totalFirstCnt  totalSecondCnt  totalThirdCnt
# 0           500635               0              0
# 1           546277               0              0
# 2           583658               0              0
# 3           587884               0              0
# 4           588958               0              0
# ..             ...             ...            ...
# 235       41138792        38681202          81417
# 236       41224561        38804722         115906
# 237       41269453        38895232         172338
# 238       41336297        38973579         229572
# 239       41398611        39099285         274593
#
# [240 rows x 12 columns]

# %%
to_excel(df)
